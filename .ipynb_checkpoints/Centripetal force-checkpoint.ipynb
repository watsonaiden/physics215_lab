# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# %matplotlib inline

radius = np.array([14.8, 15.9, 16.8, 18.8])/100 # original measurements in cm so divide by 100 to convert to m
period = np.array([11.3, 12.02, 12.39, 13.23])/10 # period value originally for 10 revs

period_squared = period **2 # squre period for plotting

period_error = np.array([.16,.08,.06,.09])/10 # error for 10 loops so 1/10 of error for each

period_squared_error = period_squared * 2 * (period_error/period) # error propagation for

# %%
print(period_squared_error)
def Delta(x, dy):
    D = (sum(1/dy**2))*(sum(x**2/dy**2))-(sum(x/dy**2))**2
    return D
D = Delta(radius, period_squared_error)

# error in slope
dm = np.sqrt(1/D*sum(1/period_squared_error**2))
print(dm)
# Out:
# [0.03616  0.019232 0.014868 0.023814]
# 0.9022944754540647

# %%
xnew = np.linspace(radius.min(), radius.max(), 300)
fit_line = a*xnew +b 
matrix = np.stack([radius], axis=-1)
# solve for best fit line using least squares to force passing through origin
coeff = np.linalg.lstsq(matrix, period_squared, rcond=None)[0]
fit_line_origin = coeff[0]*xnew
print(fit)
# Out:
# [134.38800571 144.37630344 152.54854703 170.70908834]

# %%
plt.figure(figsize=(15,10))
plt.title("correlation of radius to period squared")
plt.scatter(radius, period_squared)
plt.scatter(xnew, fit_line_origin, color='red')
plt.xlabel('radius (meters)')
plt.ylabel('T^2 (s^2)')
plt.annotate(f'fit line equation = {coeff[0]}x',(0.05, 0.85), xycoords='axes fraction')
plt.annotate(f'error in slope(s^2/m) = {dm}',(0.05, 0.8), xycoords='axes fraction')
plt.show()
